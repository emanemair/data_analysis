# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('sales_data.csv' )

# %%
data
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
null_values = data.isnull().sum()
null_values.sum()
# Out:
# 0

# %%
data.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
#what is the mean of customer age 
data['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %%
ax = data['Customer_Age'].plot(kind='kde' , figsize=(12,6))
ax.axvline(data['Customer_Age'].mean() , color='red' )
ax.set_title('customer_age')
# Out:
# Text(0.5, 1.0, 'customer_age')

# %%
ax = data['Customer_Age'].plot(kind='box' , figsize=(12,6),vert=False)
ax.set_title('customer_age')
# Out:
# Text(0.5, 1.0, 'customer_age')

# %%
data['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %%
ax= data['Order_Quantity'].plot(kind='kde' , figsize=(12,6))
ax.axvline(data['Order_Quantity'].mean() , color='red')
ax.set_title('Order_Quantity')
# Out:
# Text(0.5, 1.0, 'Order_Quantity')

# %%
data['Order_Quantity'].plot(kind='box' , figsize=(12,6),vert=False)
# Out:
# <AxesSubplot:>

# %%
#how many sales per year do we have ?? 
data['Year'].value_counts()
# Out:
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: Year, dtype: int64

# %%
ax = data['Year'].value_counts().plot(kind='bar' , figsize=(12,6),edgecolor='green')
ax.set_title('Sales Count Per Year')
ax.set_xlabel('Years')
ax.set_ylabel('Sales Count')
# Out:
# Text(0, 0.5, 'Sales Count')

# %%
#how many sales per month do we have 
ax = data['Month'].value_counts().plot(kind='bar', figsize=(12,6),edgecolor='green')
ax.set_title('Sales per Month')
ax.set_xlabel('Month')
ax.set_ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
ax = data['Day'].value_counts().plot(kind='kde' , figsize=(12,6))
ax.axvline(data['Day'].value_counts().mean() , color='red')
ax.set_title('Distrbutuion of sales per day')
# Out:
# Text(0.5, 1.0, 'Distrbutuion of sales per day')

# %%
data['Country'].value_counts()
# Out:
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: Country, dtype: int64

# %%
ax = data['Country'].value_counts().plot(kind='bar', figsize=(12,6),edgecolor='green')
ax.set_title('Sales Per Country')
ax.set_xlabel('Country')
ax.set_ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
data['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
data['Product'].value_counts().head(10)
# Out:
# Water Bottle - 30 oz.      10794
# Patch Kit/8 Patches        10416
# Mountain Tire Tube          6816
# AWC Logo Cap                4358
# Sport-100 Helmet, Red       4220
# Road Tire Tube              4176
# Sport-100 Helmet, Black     4152
# Fender Set - Mountain       4032
# Sport-100 Helmet, Blue      3788
# Touring Tire Tube           3702
# Name: Product, dtype: int64

# %%
ax = data['Product'].value_counts().head(10).plot(kind='bar' , figsize=(12,6))
ax.set_title('10 best seller product')
ax.set_xlabel('Product')
# Out:
# Text(0.5, 0, 'Product')

# %%
data.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))
# Out:
# <AxesSubplot:xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
data.plot(kind='scatter' , x='Country' , y='Profit')
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Profit'>

# %%
data[['Country' , 'Profit']].boxplot(by='Country' , figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'Profit'}, xlabel='[Country]'>

# %%
data[['Customer_Age'  , 'Country']].boxplot(by='Country' , figsize=(12,6))
# Out:
# <AxesSubplot:title={'center':'Customer_Age'}, xlabel='[Country]'>

# %%
data['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

data['Calculated_Date'].head()

# %%
data['Calculated_Date2'] = data[['Year' , 'Month' , 'Day']].apply(lambda x : '{}-{}-{}'.format(x[0] ,x[1] , x[2]) , axis=1)

# %%
data.drop('Calculated_Date2' , axis='columns', inplace=True)

# %%
data.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue', 'Calculated_Date'],
#       dtype='object')

# %%
data['Calculated_Date'] = pd.to_datetime(data['Calculated_Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
#how the sale evolve over the years 
ax = data['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))

# %%
data['Revenue'] += 50

# %%
data.loc[(data['Country']=='Canada') |  (data['Country'] == 'France' )].shape[0]
# Out:
# 25176

# %%
data.loc[(data['Country'] == 'Canada') | (data['Country'] == 'France')].shape[0]
# Out:
# 25176

# %%
#How many Bike Racks orders were made from Canada?
data.loc[ ( data['Country'] == 'Canada' ) & (data['Sub_Category'] == 'Bike Racks')].shape[0]
# Out:
# 104

# %%
# How many orders were made in each region (state) of France?
france_region = data.loc[data['Country'] == 'France' , 'State'].value_counts()
france_region = pd.DataFrame(data=france_region ) 
france_region.columns = ['Sales']

# %%
france_region
# Out:
#                    Sales
# Seine (Paris)       2328
# Seine Saint Denis   1684
# Nord                1670
# Hauts de Seine      1084
# Essonne              994
# Yveline              954
# Seine et Marne       394
# Moselle              386
# Loiret               382
# Val d'Oise           264
# Garonne (Haute)      208
# Val de Marne         158
# Charente-Maritime    148
# Somme                134
# Loir et Cher         120
# Pas de Calais         90

# %%
france_region.plot(kind='bar', figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
#how many sales we made per category 
data['Product_Category'].value_counts()
# Out:
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Product_Category, dtype: int64

# %%
ax = data['Product_Category'].value_counts().plot(kind='pie', figsize=(12,6))
ax.set_title('Sales Per Product Category')
ax.legend()

# %%
#sales per country
data['Country'].value_counts()
# Out:
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: Country, dtype: int64

# %%
ax = data['Country'].value_counts().plot(kind='pie' , figsize=(12,6))
ax.set_title('Sales per Category')
ax.legend()

# %%
data.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue', 'Calculated_Date'],
#       dtype='object')

# %%
data['Sub_Category'].unique()
# Out:
# array(['Bike Racks', 'Bike Stands', 'Bottles and Cages', 'Caps',
#        'Cleaners', 'Fenders', 'Gloves', 'Helmets', 'Hydration Packs',
#        'Jerseys', 'Mountain Bikes', 'Road Bikes', 'Shorts', 'Socks',
#        'Tires and Tubes', 'Touring Bikes', 'Vests'], dtype=object)

# %%
data['Product_Category'].unique()
# Out:
# array(['Accessories', 'Clothing', 'Bikes'], dtype=object)

# %%
#How many orders were made per accessory sub-categories?
accessories = data.loc[data['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()

# %%
ax= accessories.plot(kind='bar' , figsize=(12,6))
ax.set_title('orders were made per accessory sub-categories')
ax.set_xlabel('accessory sub-categories')
ax.set_ylabel('Sales Count')
# Out:
# Text(0, 0.5, 'Sales Count')
