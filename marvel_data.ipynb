# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.4.4

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
marvel_df = pd.DataFrame(data=marvel_data)

# %%
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
marvel_df.columns= ['Name', 'Sex', 'First_Appearance']

# %%
marvel_df
# Out:
#                 Name     Sex  First_Appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
marvel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              20 non-null     object
#  1   Sex               20 non-null     object
#  2   First_Appearance  20 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 608.0+ bytes

# %%
marvel_df.describe()
# Out:
#        First_Appearance
# count         20.000000
# mean        1961.850000
# std            8.405982
# min         1939.000000
# 25%         1961.750000
# 50%         1963.000000
# 75%         1964.000000
# max         1975.000000

# %%
marvel_df['Name'].unique()
# Out:
# array(['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor',
#        'Thing', 'Mister Fantastic', 'Hulk', 'Beast', 'Invisible Woman',
#        'Storm', 'Namor', 'Hawkeye', 'Daredevil', 'Doctor Strange',
#        'Hank Pym', 'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'],
#       dtype=object)

# %%
marvel_df['Name'] = marvel_df['Name'].str.strip()

# %%
marvel_df.set_index('Name' , inplace=True)

# %%
marvel_df
# Out:
#                      Sex  First_Appearance  Year_Since
# Name
# Spider-Man        female              1962          62
# Captain America   female              1941          83
# Wolverine         female              1974          50
# Iron Man          female              1963          61
# Thor              female              1963          61
# Thing             female              1961          63
# Mister Fantastic  female              1961          63
# Hulk              female              1962          62
# Beast             female              1963          61
# Invisible Woman   female              1961          63
# Storm             female              1975          49
# Hawkeye           female              1964          60
# Daredevil         female              1964          60
# Doctor Strange    female              1963          61
# Scarlet Witch     female              1964          60
# Wasp              female              1963          61
# ...

# %%
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis= 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9532\2346315847.py in <module>
# ----> 1 marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis= 0)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
marvel_df
# Out:
#                      Sex  First_Appearance  Year_Since
# Name
# Spider-Man        female              1962          62
# Captain America   female              1941          83
# Wolverine         female              1974          50
# Iron Man          female              1963          61
# Thor              female              1963          61
# Thing             female              1961          63
# Mister Fantastic  female              1961          63
# Hulk              female              1962          62
# Beast             female              1963          61
# Invisible Woman   female              1961          63
# Storm             female              1975          49
# Hawkeye           female              1964          60
# Daredevil         female              1964          60
# Doctor Strange    female              1963          61
# Scarlet Witch     female              1964          60
# Wasp              female              1963          61
# ...

# %%
marvel_df.iloc[:5, ]
# Out:
#                     Sex  First_Appearance  Year_Since
# Name
# Spider-Man       female              1962          62
# Captain America  female              1941          83
# Wolverine        female              1974          50
# Iron Man         female              1963          61
# Thor             female              1963          61

# %%
marvel_df.iloc[-5:,]
# Out:
#                    Sex  First_Appearance  Year_Since
# Name
# Doctor Strange  female              1963          61
# Scarlet Witch   female              1964          60
# Wasp            female              1963          61
# Black Widow     female              1964          60
# Vision          female              1964          60

# %%
marvel_df.iloc[1:-1,]
# Out:
#                      Sex  First_Appearance  Year_Since
# Name
# Captain America   female              1941          83
# Wolverine         female              1974          50
# Iron Man          female              1963          61
# Thor              female              1963          61
# Thing             female              1961          63
# Mister Fantastic  female              1961          63
# Hulk              female              1962          62
# Beast             female              1963          61
# Invisible Woman   female              1961          63
# Storm             female              1975          49
# Hawkeye           female              1964          60
# Daredevil         female              1964          60
# Doctor Strange    female              1963          61
# Scarlet Witch     female              1964          60
# Wasp              female              1963          61
# Black Widow       female              1964          60

# %%
marvel_df.iloc[[0,-1]]
# Out:
#                Sex  First_Appearance  Year_Since
# Name
# Spider-Man  female              1962          62
# Vision      female              1964          60

# %%
marvel_df.loc['Vision','First_Appearance'] = 1964

# %%
marvel_df['Year_Since'] = 2024 -  marvel_df['First_Appearance']

# %%
marvel_df
# Out:
#                      Sex  First_Appearance  Year_Since
# Name
# Spider-Man          male              1962          62
# Captain America     male              1941          83
# Wolverine           male              1974          50
# Iron Man            male              1963          61
# Thor                male              1963          61
# Thing               male              1961          63
# Mister Fantastic    male              1961          63
# Hulk                male              1962          62
# Beast               male              1963          61
# Invisible Woman   female              1961          63
# Storm             female              1975          49
# Hawkeye             male              1964          60
# Daredevil           male              1964          60
# Doctor Strange      male              1963          61
# Scarlet Witch     female              1964          60
# Wasp              female              1963          61
# ...

# %%
marvel_df[marvel_df['Sex'] == 'female']
# Out:
#                      Sex  First_Appearance  Year_Since
# Name
# Spider-Man        female              1962          62
# Captain America   female              1941          83
# Wolverine         female              1974          50
# Iron Man          female              1963          61
# Thor              female              1963          61
# Thing             female              1961          63
# Mister Fantastic  female              1961          63
# Hulk              female              1962          62
# Beast             female              1963          61
# Invisible Woman   female              1961          63
# Storm             female              1975          49
# Hawkeye           female              1964          60
# Daredevil         female              1964          60
# Doctor Strange    female              1963          61
# Scarlet Witch     female              1964          60
# Wasp              female              1963          61
# ...

# %%
mask = marvel_df['First_Appearance'] > 1970
marvel_df[mask]
# Out:
#               Sex  First_Appearance  Year_Since
# Name
# Wolverine  female              1974          50
# Storm      female              1975          49

# %%
mask = (marvel_df['First_Appearance'] > 1972) & (marvel_df['Sex'] == 'female')
marvel_df[mask]
# Out:
#               Sex  First_Appearance  Year_Since
# Name
# Wolverine  female              1974          50
# Storm      female              1975          49

# %%
marvel_df.describe()
# Out:
#        First_Appearance  Year_Since
# count         18.000000   18.000000
# mean        1962.888889   61.111111
# std            6.720372    6.720372
# min         1941.000000   49.000000
# 25%         1962.000000   60.000000
# 50%         1963.000000   61.000000
# 75%         1964.000000   62.000000
# max         1975.000000   83.000000

# %%
mask = marvel_df['First_Appearance'] == marvel_df['First_Appearance'].min()
marvel_df[mask]
# Out:
#                     Sex  First_Appearance  Year_Since
# Name
# Captain America  female              1941          83

# %%
marvel_df
# Out:
#                      Sex  First_Appearance  Year_Since
# Name
# Spider-Man        female              1962          62
# Captain America   female              1941          83
# Wolverine         female              1974          50
# Iron Man          female              1963          61
# Thor              female              1963          61
# Thing             female              1961          63
# Mister Fantastic  female              1961          63
# Hulk              female              1962          62
# Beast             female              1963          61
# Invisible Woman   female              1961          63
# Storm             female              1975          49
# Hawkeye           female              1964          60
# Daredevil         female              1964          60
# Doctor Strange    female              1963          61
# Scarlet Witch     female              1964          60
# Wasp              female              1963          61
# ...

# %%
marvel_df = marvel_df.reset_index()

# %%
marvel_df
# Out:
#                 Name     Sex  First_Appearance  Year_Since
# 0         Spider-Man  female              1962          62
# 1    Captain America  female              1941          83
# 2          Wolverine  female              1974          50
# 3           Iron Man  female              1963          61
# 4               Thor  female              1963          61
# 5              Thing  female              1961          63
# 6   Mister Fantastic  female              1961          63
# 7               Hulk  female              1962          62
# 8              Beast  female              1963          61
# 9    Invisible Woman  female              1961          63
# 10             Storm  female              1975          49
# 11           Hawkeye  female              1964          60
# 12         Daredevil  female              1964          60
# 13    Doctor Strange  female              1963          61
# 14     Scarlet Witch  female              1964          60
# ...

# %%
marvel_df.plot()
# Out:
# <AxesSubplot:>

# %%
plt.hist(marvel_df['First_Appearance'] , edgecolor='green')
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  3., 12.,  0.,  0.,  2.]),
#  array([1941. , 1944.4, 1947.8, 1951.2, 1954.6, 1958. , 1961.4, 1964.8,
#         1968.2, 1971.6, 1975. ]),
#  <BarContainer object of 10 artists>)

# %%
marvel_df['First_Appearance'].mean()
# Out:
# 1962.888888888889

# %%
ax= marvel_df['First_Appearance'].plot(kind='density', figsize=(14,6)) # kde
ax.axvline(marvel_df['First_Appearance'].mean() , color = 'red')
